# %% [markdown]
# ## TITLE
#
# * description of what the notebook does
#
# ### The Data
#
# * link to source for data and description from site

# %%
import warnings
warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
accidental_drug_deaths_df = pd.read_csv('../data/accidental_drug_deaths_CT.csv')

# %%
accidental_drug_deaths_df
# Out:
#            ID        Date    Date Type   Age     Sex   Race Residence City  \
# 0     12-0187  07/17/2012  DateofDeath  34.0  Female  White        MAHOPAC
# 1     12-0258  10/01/2012  DateofDeath  51.0    Male  White       PORTLAND
# 2     13-0146  04/28/2013  DateofDeath  28.0    Male  White            NaN
# 3     14-0150  04/06/2014  DateofDeath  46.0    Male  White      WATERBURY
# 4     14-0183  04/27/2014  DateofDeath  52.0    Male  White     NEW LONDON
# ...       ...         ...          ...   ...     ...    ...            ...
# 7674  14-0128  03/20/2014  DateofDeath  25.0    Male  White        MILFORD
# 7675  20-1217  11/19/2020  DateofDeath  62.0  Female  White       STAMFORD
# 7676  20-1138  10/31/2020  DateofDeath  50.0  Female  White    NEW BRITAIN
# 7677  16-0640  09/17/2016  DateofDeath  36.0    Male  White        SHELTON
# 7678  19-0963  10/25/2019  DateofDeath  33.0    Male  White      NEW HAVEN
#
#      Residence County Residence State    Death City  ...  \
# 0              PUTNAM             NaN       DANBURY  ...
# 1           MIDDLESEX             NaN      PORTLAND  ...
# 2                 NaN             NaN      HARTFORD  ...
# 3                 NaN             NaN    TORRINGTON  ...
# 4                 NaN             NaN    NEW LONDON  ...
# ...               ...             ...           ...  ...
# 7674              NaN             NaN  WETHERSFIELD  ...
# 7675        FAIRFIELD              CT      STAMFORD  ...
# 7676         HARTFORD              CT   NEW BRITAIN  ...
# 7677        FAIRFIELD              CT       SHELTON  ...
# 7678        NEW HAVEN              CT     NEW HAVEN  ...
#
#      Morphine (Not Heroin) Hydromorphone Xylazine   Other Opiate NOS  \
# 0                      NaN           NaN      NaN  Duster        NaN
# 1                      NaN           NaN      NaN     NaN        NaN
# 2                      NaN           NaN      NaN     NaN        NaN
# 3                      NaN           NaN      NaN     NaN        NaN
# 4                      NaN           NaN      NaN     NaN        NaN
# ...                    ...           ...      ...     ...        ...
# 7674                   NaN           NaN      NaN     NaN        NaN
# 7675                   NaN           NaN      NaN     NaN        NaN
# 7676                   NaN           NaN        Y     NaN        NaN
# 7677                   NaN           NaN      NaN     NaN        NaN
# 7678                   NaN           NaN      NaN     NaN        NaN
#
#      Any Opioid Manner of Death                               DeathCityGeo  \
# 0           NaN        Accident       DANBURY, CT\n(41.393666, -73.451539)
# 1           NaN        Accident      PORTLAND, CT\n(41.581345, -72.634112)
# 2           NaN        Accident      HARTFORD, CT\n(41.765775, -72.673356)
# 3           NaN        Accident    TORRINGTON, CT\n(41.812186, -73.101552)
# 4           NaN        Accident    NEW LONDON, CT\n(41.355167, -72.099561)
# ...         ...             ...                                        ...
# 7674        NaN        Accident  WETHERSFIELD, CT\n(41.712487, -72.663607)
# 7675          Y        Accident      Stamford, CT\n(41.051924, -73.539475)
# 7676          Y        Accident   New Britain, CT\n(41.667528, -72.783437)
# 7677          Y        Accident       SHELTON, CT\n(41.316843, -73.092968)
# 7678          Y        Accident     New Haven, CT\n(41.308252, -72.924161)
#
#                               ResidenceCityGeo  \
# 0                                          NaN
# 1        PORTLAND, CT\n(41.581345, -72.634112)
# 2                  CT\n(41.575155, -72.738288)
# 3       WATERBURY, CT\n(41.554261, -73.043069)
# 4      NEW LONDON, CT\n(41.355167, -72.099561)
# ...                                        ...
# 7674      MILFORD, CT\n(41.224276, -73.057564)
# 7675     STAMFORD, CT\n(41.051924, -73.539475)
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)
# 7677      SHELTON, CT\n(41.316843, -73.092968)
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)
#
#                                  InjuryCityGeo
# 0                  CT\n(41.575155, -72.738288)
# 1                  CT\n(41.575155, -72.738288)
# 2                  CT\n(41.575155, -72.738288)
# 3                  CT\n(41.575155, -72.738288)
# 4                  CT\n(41.575155, -72.738288)
# ...                                        ...
# 7674               CT\n(41.575155, -72.738288)
# 7675     STAMFORD, CT\n(41.051924, -73.539475)
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)
# 7677      SHELTON, CT\n(41.316843, -73.092968)
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)
#
# [7679 rows x 42 columns]

# %% [markdown]
# # Data Frame Examination:

# %% [markdown]
# ### What are the dimensions (number of rows and columns) of the data frame?

# %%
accidental_drug_deaths_df.shape
# Out:
# (7679, 42)

# %% [markdown]
# There are 7679 rows and 42 columns.

# %% [markdown]
# ### What does each row represent?

# %% [markdown]
# Each row represents a date with an accident drug death of a person in CT.

# %% [markdown]
# ### What do the columns mean?

# %% [markdown]
# * ID: a number ID for each person
# * Date: The date
# * Date type: Describes if the date is for the date of death or the date reported
# * Age: age in years
# * Sex: sex (male or female)
# * Race: race
# * Residence city: the city they resided in
# * Residence county: the county they resided in
# * Residence state: the state (note that some of the states are not CT for some reason so we should filter those out)
# * Death city: they city they died in
# * Location: where they died
# * Description of injury: descirbed if the drug was injected, huffed, etc.
# * Injury place: where the drug was used
# * Injury city: city where the drug was used
# * Cause of death: The exact cause of the death (string)
# * Then, there are a bunch of columns listing different drugs. A 'Y' is placed in the column that describes the correct drug used. We want to look at heroin, fentanyl, fentanyl analogue, oxycodone, oxymorphone, hydrocodone, methadone, morphine, hydromorphone.
# * Then, they have a column for any opioid, this will be extremely helpful. If there is a 'y' in the any opioid column, this means the person overdosed on an opioid.
# * Manner of death: explains if it was an accident
# * The last 3 columns gives the geolocation so we can use geo json to create a map of where the opioid overdoses occured.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Rename Columns

# %% [markdown]
# First, let's look at the current name of the columns

# %%
accidental_drug_deaths_df.columns
# Out:
# Index(['ID', 'Date', 'Date Type', 'Age', 'Sex', 'Race', 'Residence City',
#        'Residence County', 'Residence State', 'Death City', 'Death County',
#        'Location', 'Location if Other', 'Description of Injury',
#        'Injury Place', 'Injury City', 'Injury County', 'Injury State',
#        'Cause of Death', 'Other Significant Conditions ', 'Heroin', 'Cocaine',
#        'Fentanyl', 'Fentanyl Analogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad',
#        'Morphine (Not Heroin)', 'Hydromorphone', 'Xylazine', 'Other',
#        'Opiate NOS', 'Any Opioid', 'Manner of Death', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %% [markdown]
# One thing that I notice is that the columns have spaces in them. Let's rename these so that there are no spaces.

# %%
colname_map = {'Date Type': 'Date_Type',
               'Residence City': 'Residence_City', 
               'Residence County': 'Residence_County', 
               'Residence State':'Residence_State',
               'Death City':'Death_City', 
               'Death County':'Death_County', 
               'Location if Other' : 'Location_if_Other', 
               'Description of Injury' : 'Description_of_Injury', 
               'Injury Place' : 'Injury_Place', 
               'Injury City' : 'Injury_City', 
               'Injury County' : 'Injury_County', 
               'Injury State' : 'Injury_State', 
               'Cause of Death' : 'Cause_of_Death', 
               'Other Significant Conditions ': 'Other_Significant_Conditions', 
               'Fentanyl Analogue':'Fentanyl_Analogue', 
               'Morphine (Not Heroin)':'Morphine_Not_Heroin', 
               'Opiate NOS':'Opiate_NOS', 
               'Any Opioid':'Any_Opioid', 
               'Manner of Death':'Manner_of_Death'
              }

accidental_drug_deaths_df = accidental_drug_deaths_df.rename(columns=colname_map)

# %%
accidental_drug_deaths_df.columns
# Out:
# Index(['ID', 'Date', 'Date_Type', 'Age', 'Sex', 'Race', 'Residence_City',
#        'Residence_County', 'Residence_State', 'Death_City', 'Death_County',
#        'Location', 'Location_if_Other', 'Description_of_Injury',
#        'Injury_Place', 'Injury_City', 'Injury_County', 'Injury_State',
#        'Cause_of_Death', 'Other_Significant_Conditions', 'Heroin', 'Cocaine',
#        'Fentanyl', 'Fentanyl_Analogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad',
#        'Morphine_Not_Heroin', 'Hydromorphone', 'Xylazine', 'Other',
#        'Opiate_NOS', 'Any_Opioid', 'Manner_of_Death', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %% [markdown]
# ### Remove unwanted rows or columns

# %% [markdown]
# This data set is very big and has some columns that we are not going to use for our data analysis. Let's remove those columns now.

# %%
accidental_drug_deaths_df = accidental_drug_deaths_df.drop(['Date_Type', 'Other_Significant_Conditions'], axis=1)

# %% [markdown]
# ### Save the cleaned data frame

# %%
accidental_drug_deaths_df.to_csv('../data/accidental_drug_deaths_CT_clean.csv', index=False)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Examine the distribution in the relevant columns

# %% [markdown]
# Let's start by looking at the range of dates in this data set.

# %%
accidental_drug_deaths_df['Date'] = pd.to_datetime(accidental_drug_deaths_df['Date'])

# %%
accidental_drug_deaths_df['Date'].nunique()
# Out:
# 2803

# %% [markdown]
# There are 2803 unique dates in the data set.

# %%
accidental_drug_deaths_df.sort_values('Date')
# Out:
#            ID       Date    Date_Type   Age   Sex   Race Residence_City  \
# 231   12-0001 2012-01-01  DateofDeath  35.0  Male  White         HEBRON
# 1839  12-0002 2012-01-03  DateofDeath  41.0  Male  White        BRISTOL
# 3415  12-0003 2012-01-04  DateofDeath  61.0  Male  Black        DANBURY
# 4956  12-0004 2012-01-05  DateofDeath  51.0  Male  White      STRATFORD
# 6969  12-0005 2012-01-07  DateofDeath  45.0  Male  White       HARTFORD
# ...       ...        ...          ...   ...   ...    ...            ...
# 3418  20-1374 2020-12-31  DateofDeath  64.0  Male  White        NORWICH
# 1586  20-1373 2020-12-31  DateofDeath  32.0  Male  White   NEW HARTFORD
# 6068  20-1372 2020-12-31  DateofDeath  28.0  Male  White        LEDYARD
# 125   15-0729        NaT          NaN  28.0  Male  White            NaN
# 6442  15-0728        NaT          NaN   NaN   NaN    NaN            NaN
#
#      Residence_County Residence_State    Death_City  ... Morphine_Not_Heroin  \
# 231           TOLLAND             NaN        HEBRON  ...                 NaN
# 1839         HARTFORD             NaN       BRISTOL  ...                 NaN
# 3415        FAIRFIELD             NaN       DANBURY  ...                 NaN
# 4956        FAIRFIELD             NaN    BRIDGEPORT  ...                 NaN
# 6969         HARTFORD             NaN      HARTFORD  ...                 NaN
# ...               ...             ...           ...  ...                 ...
# 3418       NEW LONDON              CT       NORWICH  ...                 NaN
# 1586       LITCHFIELD              CT  NEW HARTFORD  ...                 NaN
# 6068       NEW LONDON              CT       LEDYARD  ...                 NaN
# 125               NaN             NaN           NaN  ...                 NaN
# 6442              NaN             NaN           NaN  ...                 NaN
#
#      Hydromorphone Xylazine Other Opiate_NOS Any_Opioid Manner_of_Death  \
# 231            NaN      NaN   NaN        NaN        NaN        Accident
# 1839           NaN      NaN   NaN        NaN        NaN        Accident
# 3415           NaN      NaN   NaN        NaN        NaN        Accident
# 4956           NaN      NaN   NaN        NaN        NaN        Accident
# 6969           NaN      NaN   NaN        NaN        NaN        Accident
# ...            ...      ...   ...        ...        ...             ...
# 3418           NaN      NaN   NaN        NaN          Y        Accident
# 1586           NaN        Y   NaN        NaN          Y        Accident
# 6068           NaN      NaN   NaN        NaN          Y        Accident
# 125            NaN      NaN   2-A        NaN        NaN             NaN
# 6442           NaN      NaN   NaN        NaN        NaN        Accident
#
#                                    DeathCityGeo  \
# 231         HEBRON, CT\n(41.658069, -72.366324)
# 1839       BRISTOL, CT\n(41.673037, -72.945791)
# 3415       DANBURY, CT\n(41.393666, -73.451539)
# 4956    BRIDGEPORT, CT\n(41.179195, -73.189476)
# 6969      HARTFORD, CT\n(41.765775, -72.673356)
# ...                                         ...
# 3418       Norwich, CT\n(41.524304, -72.075821)
# 1586  New Hartford, CT\n(41.879454, -72.976047)
# 6068       Ledyard, CT\n(41.445618, -72.018188)
# 125                 CT\n(41.575155, -72.738288)
# 6442                CT\n(41.575155, -72.738288)
#
#                                ResidenceCityGeo  \
# 231         HEBRON, CT\n(41.658069, -72.366324)
# 1839       BRISTOL, CT\n(41.673037, -72.945791)
# 3415       DANBURY, CT\n(41.393666, -73.451539)
# 4956     STRATFORD, CT\n(41.200888, -73.131323)
# 6969      HARTFORD, CT\n(41.765775, -72.673356)
# ...                                         ...
# 3418       NORWICH, CT\n(41.524304, -72.075821)
# 1586  NEW HARTFORD, CT\n(41.879454, -72.976047)
# 6068       LEDYARD, CT\n(41.445618, -72.018188)
# 125                 CT\n(41.575155, -72.738288)
# 6442                CT\n(41.575155, -72.738288)
#
#                                   InjuryCityGeo
# 231                 CT\n(41.575155, -72.738288)
# 1839                CT\n(41.575155, -72.738288)
# 3415                CT\n(41.575155, -72.738288)
# 4956                CT\n(41.575155, -72.738288)
# 6969                CT\n(41.575155, -72.738288)
# ...                                         ...
# 3418       NORWICH, CT\n(41.524304, -72.075821)
# 1586  NEW HARTFORD, CT\n(41.879454, -72.976047)
# 6068       LEDYARD, CT\n(41.445618, -72.018188)
# 125      STRATFORD, CT\n(41.200888, -73.131323)
# 6442                CT\n(41.575155, -72.738288)
#
# [7679 rows x 42 columns]

# %%
# get the range (min and max) of the Date
accidental_drug_deaths_df['Date'].agg(['min', 'max'])
# Out:
# min   2012-01-01
# max   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# The dates range from January 1, 2012 to December 31, 2020.

# %% [markdown]
# Next, let's look at the number of deaths that involved an opioid of some sort.

# %%
opioid_filter = accidental_drug_deaths_df['Any_Opioid'] == 'Y'
opioid_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7674    False
# 7675     True
# 7676     True
# 7677     True
# 7678     True
# Name: Any_Opioid, Length: 7679, dtype: bool

# %%
accidental_drug_deaths_df[opioid_filter]
# Out:
#            ID       Date   Age     Sex   Race Residence_City Residence_County  \
# 6     15-0052 2015-02-01  52.0    Male  White     MIDDLETOWN        MIDDLESEX
# 7     15-0239 2015-05-21  32.0    Male  White        ORLANDO           ORANGE
# 9     15-0365 2015-07-17  42.0    Male  White     CANTERBURY          WINDHAM
# 10    15-0715 2015-12-23  44.0    Male  White            NaN              NaN
# 11    16-0032 2016-01-17  26.0    Male  Black        BRISTOL         HARTFORD
# ...       ...        ...   ...     ...    ...            ...              ...
# 7673  18-0648 2018-08-18  51.0  Female  Black      WATERBURY        NEW HAVEN
# 7675  20-1217 2020-11-19  62.0  Female  White       STAMFORD        FAIRFIELD
# 7676  20-1138 2020-10-31  50.0  Female  White    NEW BRITAIN         HARTFORD
# 7677  16-0640 2016-09-17  36.0    Male  White        SHELTON        FAIRFIELD
# 7678  19-0963 2019-10-25  33.0    Male  White      NEW HAVEN        NEW HAVEN
#
#      Residence_State        Death_City Death_County  ... Morphine_Not_Heroin  \
# 6                 CT        MIDDLETOWN    MIDDLESEX  ...                 NaN
# 7                 FL        TORRINGTON   LITCHFIELD  ...                 NaN
# 9                 CT        CANTERBURY      WINDHAM  ...                 NaN
# 10               NaN  STAFFORD SPRINGS      TOLLAND  ...                 NaN
# 11                CT           BRISTOL          NaN  ...                 NaN
# ...              ...               ...          ...  ...                 ...
# 7673              CT          HARTFORD     HARTFORD  ...                 NaN
# 7675              CT          STAMFORD    FAIRFIELD  ...                 NaN
# 7676              CT       NEW BRITAIN     HARTFORD  ...                 NaN
# 7677              CT           SHELTON          NaN  ...                 NaN
# 7678              CT         NEW HAVEN    NEW HAVEN  ...                 NaN
#
#      Hydromorphone Xylazine Other Opiate_NOS Any_Opioid Manner_of_Death  \
# 6              NaN      NaN   NaN        NaN          Y        Accident
# 7              NaN      NaN   NaN        NaN          Y        Accident
# 9              NaN      NaN   NaN        NaN          Y        Accident
# 10             NaN      NaN   NaN        NaN          Y        Accident
# 11             NaN      NaN   NaN        NaN          Y        Accident
# ...            ...      ...   ...        ...        ...             ...
# 7673           NaN      NaN   NaN        NaN          Y        Accident
# 7675           NaN      NaN   NaN        NaN          Y        Accident
# 7676           NaN        Y   NaN        NaN          Y        Accident
# 7677           NaN      NaN   NaN        NaN          Y        Accident
# 7678           NaN      NaN   NaN        NaN          Y        Accident
#
#                                        DeathCityGeo  \
# 6           MIDDLETOWN, CT\n(41.544654, -72.651713)
# 7           TORRINGTON, CT\n(41.812186, -73.101552)
# 9           CANTERBURY, CT\n(41.698351, -71.971118)
# 10    STAFFORD SPRINGS, CT\n(41.953931, -72.302901)
# 11             BRISTOL, CT\n(41.673037, -72.945791)
# ...                                             ...
# 7673          HARTFORD, CT\n(41.765775, -72.673356)
# 7675          Stamford, CT\n(41.051924, -73.539475)
# 7676       New Britain, CT\n(41.667528, -72.783437)
# 7677           SHELTON, CT\n(41.316843, -73.092968)
# 7678         New Haven, CT\n(41.308252, -72.924161)
#
#                               ResidenceCityGeo  \
# 6      MIDDLETOWN, CT\n(41.544654, -72.651713)
# 7                                          NaN
# 9      CANTERBURY, CT\n(41.698351, -71.971118)
# 10                 CT\n(41.575155, -72.738288)
# 11        BRISTOL, CT\n(41.673037, -72.945791)
# ...                                        ...
# 7673    WATERBURY, CT\n(41.554261, -73.043069)
# 7675     STAMFORD, CT\n(41.051924, -73.539475)
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)
# 7677      SHELTON, CT\n(41.316843, -73.092968)
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)
#
#                                  InjuryCityGeo
# 6                  CT\n(41.575155, -72.738288)
# 7                  CT\n(41.575155, -72.738288)
# 9                  CT\n(41.575155, -72.738288)
# 10                 CT\n(41.575155, -72.738288)
# 11        BRISTOL, CT\n(41.673037, -72.945791)
# ...                                        ...
# 7673     HARTFORD, CT\n(41.765775, -72.673356)
# 7675     STAMFORD, CT\n(41.051924, -73.539475)
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)
# 7677      SHELTON, CT\n(41.316843, -73.092968)
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)
#
# [4860 rows x 40 columns]

# %% [markdown]
# Since there are 4860 rows in the opioid filtered dataframe, which only contains the rows of people who died via an opioid, and there are a total of 7679 in the bigger dataframe, this means that over half of the overdoses from January 1, 2012 - December 31, 2020 were due to opioids.

# %%
# distribution of opioid deaths by city
accidental_drug_deaths_df[opioid_filter]['Residence_City'].value_counts().head(30)
# Out:
# HARTFORD         329
# WATERBURY        299
# BRIDGEPORT       235
# NEW HAVEN        232
# NEW BRITAIN      180
# BRISTOL          134
# MERIDEN          106
# NORWICH           98
# MANCHESTER        97
# TORRINGTON        94
# EAST HARTFORD     88
# WEST HAVEN        80
# STRATFORD         79
# DANBURY           76
# MIDDLETOWN        76
# NEW LONDON        76
# ENFIELD           67
# HAMDEN            60
# NORWALK           60
# MILFORD           55
# NAUGATUCK         53
# EAST HAVEN        51
# STAMFORD          50
# SHELTON           46
# WALLINGFORD       44
# SOUTHINGTON       41
# ANSONIA           41
# GROTON            40
# VERNON            39
# BRANFORD          38
# Name: Residence_City, dtype: int64

# %% [markdown]
# ### Checking years in data

# %%
pd.to_datetime(accidental_drug_deaths_df['Date']).dt.year.value_counts()
# Out:
# 2020.0    1374
# 2019.0    1200
# 2017.0    1038
# 2018.0    1018
# 2016.0     917
# 2015.0     727
# 2014.0     558
# 2013.0     490
# 2012.0     355
# Name: Date, dtype: int64

# %% [markdown]
# ### What observations and questions do you have after exploring the data?

# %% [markdown]
# After exploring the data, we see that 4860 deaths from 2012-2020 were due to opioids. In our project, we want to further explore if the trend in these deaths have increased or decreased? Which specific opioid is causing the most deaths? Is there a strong correlation between opioid deaths and opioid prescriptions? Are certain locations in CT more prone to opioid deaths than otherss?
